# %%
from unet_model import unet_model
from testing import test

model = unet_model(n_channels=3, n_classes=1)

model_path1 = 'models/unet/unet_model_50.pth'
results_path1 = 'results_unet_50'
print("Testing model with 50 epochs:")
test(model_path1, results_path1, model)


model_path2 = 'models/unet/unet_model_150.pth'
results_path2 = 'results_unet_150'
print("Testing model with 150 epochs:")
test(model_path2, results_path2, model)
# Out:
# unet_model(
#   (inc): DoubleConv(
#     (double_conv): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#   )
#   (down1): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
# ...
